# %%
import pandas as pd
from sqlalchemy import create_engine
from mysql.connector import Error

# %%
Db1 = "/Users/hessari/Desktop/Tableau-HW/Resources/JC-201801-citibike-tripdata.csv"
Db2 = "/Users/hessari/Desktop/Tableau-HW/Resources/JC-201802-citibike-tripdata.csv"
Db3 = "/Users/hessari/Desktop/Tableau-HW/Resources/JC-201803-citibike-tripdata.csv"
Db4 = "/Users/hessari/Desktop/Tableau-HW/Resources/JC-201805-citibike-tripdata.csv"
Db5 = "/Users/hessari/Desktop/Tableau-HW/Resources/JC-201806-citibike-tripdata.csv"
Db6 = "/Users/hessari/Desktop/Tableau-HW/Resources/JC-201807-citibike-tripdata.csv"

# %%
Db1_df = pd.read_csv(Db1)
Db1_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
Db2_df = pd.read_csv(Db2)
Db2_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           134  2018-02-01 07:38:15.8650  2018-02-01 07:40:30.5820
# 1           413  2018-02-01 08:19:35.8160  2018-02-01 08:26:29.6490
# 2            77  2018-02-01 08:31:03.0860  2018-02-01 08:32:20.3510
# 3           404  2018-02-01 15:23:15.0850  2018-02-01 15:29:59.9300
# 4           230  2018-02-01 15:26:01.8240  2018-02-01 15:29:52.5440
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3184      Paulus Hook
# ...

# %%
Db3_df = pd.read_csv(Db3)
Db3_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           329  2018-03-01 06:37:37.0380  2018-03-01 06:43:06.5520
# 1           118  2018-03-01 07:37:30.1210  2018-03-01 07:39:28.3910
# 2            76  2018-03-01 08:26:17.9390  2018-03-01 08:27:34.6770
# 3           578  2018-03-01 12:10:36.2160  2018-03-01 12:20:14.8690
# 4           485  2018-03-01 12:21:47.8800  2018-03-01 12:29:53.2990
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3202     Newport PATH
# ...

# %%
Winter_df = [Db1_df, Db2_df, Db3_df]
Winter_df = pd.concat(Winter_df)

# %%
Winter_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
Winter_df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
Winter_df = Winter_df.rename(index=str, columns={"start station id": "start_station_id", "start station name": "start_station_name", 
                                                 "start station latitude": "start_station_latitude", "start station longitude": "start_station_longitude", 
                                                "end station id": "end_station_id", "end station name": "end_station_name", "end station latitude": "end_station_latitude",
                                                "end station longitude": "end_station_longitude", "birth year": "birth_year"})

# %%
Winter_df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start_station_id',
#        'start_station_name', 'start_station_latitude',
#        'start_station_longitude', 'end_station_id', 'end_station_name',
#        'end_station_latitude', 'end_station_longitude', 'bikeid', 'usertype',
#        'birth_year', 'gender'],
#       dtype='object')

# %%
Db4_df = pd.read_csv(Db4)
Db5_df = pd.read_csv(Db5)
Db6_df = pd.read_csv(Db6)

# %%
Summer_df = [Db4_df, Db5_df, Db6_df]
Summer_df = pd.concat(Summer_df)

# %%
Summer_df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
Summer_df = Summer_df.rename(index=str, columns={"start station id": "start_station_id", "start station name": "start_station_name", 
                                                 "start station latitude": "start_station_latitude", "start station longitude": "start_station_longitude", 
                                                "end station id": "end_station_id", "end station name": "end_station_name", "end station latitude": "end_station_latitude",
                                                "end station longitude": "end_station_longitude", "birth year": "birth_year"})

# %%
Summer_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           131  2018-05-01 07:29:57.5490  2018-05-01 07:32:08.6160
# 1            73  2018-05-01 08:13:58.2560  2018-05-01 08:15:11.9230
# 2          4929  2018-05-01 08:17:21.3110  2018-05-01 09:39:31.0770
# 3           432  2018-05-01 08:25:58.7150  2018-05-01 08:33:10.8960
# 4           432  2018-05-01 08:28:09.9160  2018-05-01 08:35:22.1440
#
#    start_station_id start_station_name  start_station_latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start_station_longitude  end_station_id end_station_name  \
# 0               -74.033459            3184      Paulus Hook
# ...

# %%
# !pip install mysql-connector

# %%
Summer_df = Summer_df.reset_index(drop=True)

# %%
Winter_df = Winter_df.reset_index(drop=True)

# %%
rds_connecting_string= "root:Kabul123@localhost:3306/City_Biking"
engine= create_engine('mysql+pymysql://{}'.format(rds_connecting_string))

# %%
Winter_df.to_sql(name='Winter_df', con=engine, if_exists='append', index=True)

# %%
Summer_df.to_sql(name='Summer_df', con=engine, if_exists='append', index=True)
